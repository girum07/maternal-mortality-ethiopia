# %%
# Maternal Mortality Trend in Ethiopia

### Report-Style Data Analysis Using DHS/HDX Dataset

# %%
## Objective

#The objective of this analysis is to examine maternal mortality trends in Ethiopia across survey years using DHS/HDX data and determine whether mortality indicators show improvement over time.

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.data_cleaning import load_data, filter_indicator
from src.analysis import compute_trend
from src.visualization import plot_trend

# %%
df = load_data("../data/raw/maternal_mortality.csv")

df.head()
# Out:
#   ISO3  DataId                                          Indicator      Value  \
# 0  ETH   12924           Female deaths that are pregnancy-related      25.30
# 1  ETH   12919                 Number of pregnancy-related deaths     263.00
# 2  ETH   12921  Years of exposure to the risk of mortality for...  156334.00
# 3  ETH   12922  Years of exposure to the risk of mortality for...  152279.00
# 4  ETH  230314                   Pregnancy-related mortality rate       1.58
#
#    Precision DHS_CountryCode CountryName  SurveyYear   SurveyId  \
# 0          1              ET    Ethiopia        2000  ET2000DHS
# 1          0              ET    Ethiopia        2000  ET2000DHS
# 2          0              ET    Ethiopia        2000  ET2000DHS
# 3          0              ET    Ethiopia        2000  ET2000DHS
# 4          2              ET    Ethiopia        2000  ET2000DHS
#
#      IndicatorId  ...  IsPreferred       SDRID  RegionId  SurveyYearLabel  \
# ...

# %%
## Data Overview

#The dataset contains maternal mortality indicators collected from DHS surveys across multiple years in Ethiopia.

# %%
df["Indicator"].unique()
# Out:
# <StringArray>
# [                         'Female deaths that are pregnancy-related',
#                                 'Number of pregnancy-related deaths',
#               'Years of exposure to the risk of mortality for women',
#  'Years of exposure to the risk of mortality for women (unweighted)',
#                                   'Pregnancy-related mortality rate',
#                                             'General fertility rate',
#                                  'Pregnancy-related mortality ratio',
#        'Pregnancy-related mortality ratio CI lower bound (PRMR-2SE)',
#        'Pregnancy-related mortality ratio CI upper bound (PRMR+2SE)',
#                           'Lifetime risk of pregnancy-related death']
# Length: 10, dtype: str

# %%
mortality_df = filter_indicator(
    df,
    "Pregnancy-related mortality rate"
)

mortality_df
# Out:
#    ISO3  DataId                         Indicator  Value  Precision  \
# 4   ETH  230314  Pregnancy-related mortality rate   1.58          2
# 14  ETH  239745  Pregnancy-related mortality rate   1.24          2
# 24  ETH  557657  Pregnancy-related mortality rate   1.14          2
# 34  ETH  657293  Pregnancy-related mortality rate   0.66          2
#
#    DHS_CountryCode CountryName  SurveyYear   SurveyId    IndicatorId  ...  \
# 4               ET    Ethiopia        2000  ET2000DHS  MM_MMRT_W_PRT  ...
# 14              ET    Ethiopia        2005  ET2005DHS  MM_MMRT_W_PRT  ...
# 24              ET    Ethiopia        2011  ET2011DHS  MM_MMRT_W_PRT  ...
# 34              ET    Ethiopia        2016  ET2016DHS  MM_MMRT_W_PRT  ...
#
#     IsPreferred       SDRID  RegionId  SurveyYearLabel SurveyType  \
# 4             1  MMMMRTWPRT       NaN             2000        DHS
# 14            1  MMMMRTWPRT       NaN             2005        DHS
# ...

# %%
trend_df = compute_trend(mortality_df)

trend_df
# Out:
#    ISO3  DataId                         Indicator  Value  Precision  \
# 4   ETH  230314  Pregnancy-related mortality rate   1.58          2
# 14  ETH  239745  Pregnancy-related mortality rate   1.24          2
# 24  ETH  557657  Pregnancy-related mortality rate   1.14          2
# 34  ETH  657293  Pregnancy-related mortality rate   0.66          2
#
#    DHS_CountryCode CountryName  SurveyYear   SurveyId    IndicatorId  ...  \
# 4               ET    Ethiopia        2000  ET2000DHS  MM_MMRT_W_PRT  ...
# 14              ET    Ethiopia        2005  ET2005DHS  MM_MMRT_W_PRT  ...
# 24              ET    Ethiopia        2011  ET2011DHS  MM_MMRT_W_PRT  ...
# 34              ET    Ethiopia        2016  ET2016DHS  MM_MMRT_W_PRT  ...
#
#     SurveyYearLabel SurveyType  DenominatorWeighted  DenominatorUnweighted  \
# 4              2000        DHS             156334.0               152279.0
# 14             2005        DHS             147433.0               143091.0
# ...

# %%
plot_trend(trend_df)

# %%
## Key Findings

 # - Maternal mortality indicators show a declining trend across survey years.
 # - The rate of decline varies between survey periods.
 # - The largest reduction appears between 2011 and 2016.

# %%
## Interpretation

# The decreasing trend may suggest improvements in maternal healthcare access, policy interventions, and health awareness programs in Ethiopia.

# However, the limited number of survey years restricts deeper time-series interpretation.

# %%
## Limitations

 # - Dataset contains limited time points.
 # - Values are survey estimates rather than continuous yearly measurements.
 # - External socioeconomic or policy variables are not included.

# %%
## Conclusion

# The analysis indicates that maternal mortality in Ethiopia has generally decreased over the observed survey years. Further analysis with more granular and continuous datasets could provide deeper insights into drivers of change.
# Out:
#   Cell In[34], line 3
#     The analysis indicates that maternal mortality in Ethiopia has generally decreased over the observed survey years. Further analysis with more granular and continuous datasets could provide deeper insights into drivers of change.
#         ^
# SyntaxError: invalid syntax
